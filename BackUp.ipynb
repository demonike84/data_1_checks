# %%
# pip install matplotlib
# pip install pandas
# pip install numpy
# pip install openpyxl

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Receiving = pd.read_excel('NFL/Receiving.xlsx', sheet_name = 'Jerry_Rice')
Receiving
# Out:
#             Player Id         Name  Position  Year                 Team  \
# 0   jerryrice/2502642  Rice, Jerry       NaN  2004     Seattle Seahawks
# 1   jerryrice/2502642  Rice, Jerry       NaN  2004      Oakland Raiders
# 2   jerryrice/2502642  Rice, Jerry       NaN  2003      Oakland Raiders
# 3   jerryrice/2502642  Rice, Jerry       NaN  2002      Oakland Raiders
# 4   jerryrice/2502642  Rice, Jerry       NaN  2001      Oakland Raiders
# 5   jerryrice/2502642  Rice, Jerry       NaN  2000  San Francisco 49ers
# 6   jerryrice/2502642  Rice, Jerry       NaN  1999  San Francisco 49ers
# 7   jerryrice/2502642  Rice, Jerry       NaN  1998  San Francisco 49ers
# 8   jerryrice/2502642  Rice, Jerry       NaN  1997  San Francisco 49ers
# 9   jerryrice/2502642  Rice, Jerry       NaN  1996  San Francisco 49ers
# 10  jerryrice/2502642  Rice, Jerry       NaN  1995  San Francisco 49ers
# 11  jerryrice/2502642  Rice, Jerry       NaN  1994  San Francisco 49ers
# ...

# %%
type(Receiving)
# Out:
# pandas.core.frame.DataFrame

# %%
Receiving.dtypes
# Out:
# Player Id                           object
# Name                                object
# Position                           float64
# Year                                 int64
# Team                                object
# Games Played                         int64
# Receptions                           int64
# Receiving Yards                      int64
# Yards Per Reception                float64
# Yards Per Game                     float64
# Longest Reception                   object
# Receiving TDs                        int64
# Receptions Longer than 20 Yards      int64
# Receptions Longer than 40 Yards      int64
# First Down Receptions                int64
# Fumbles                              int64
# dtype: object

# %%
Played = Receiving['Games Played']
Over40 = Receiving['Receptions Longer than 40 Yards']
Year = Receiving['Year']
First = Receiving['First Down Receptions']
YardsYear = Receiving['Receiving Yards']
GamesPlayed = Receiving['Games Played']
Rec = Receiving['Receptions']

# %%
type(Rec)
# Out:
# pandas.core.series.Series

# %%
plt.plot(Rec, Over40, 'o')

# %%
plt.figure(figsize = (12, 6))
plt.hist(Receiving['First Down Receptions'], bins = 9, rwidth = 0.5)
plt.xlabel('First Downs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (12, 6))
plt.hist(Receiving['Fumbles'], bins = 8, rwidth = 0.2)
plt.xlabel('Lost Balls')
plt.ylabel('Frequency')
plt.show()
